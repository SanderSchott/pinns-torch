# %% [markdown]
# ## Schrodinger
#
# Train and Test split for schrodinger

# %% [markdown]
# #### Import Libraries

# %%
from typing import Dict

import torch
import numpy as np
import lightning.pytorch as pl

import pinnstorch
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in Mesh class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")
    exact = data["uu"]
    exact_u = np.real(exact) # N x T
    exact_v = np.imag(exact) # N x T
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T
    return {"u": exact_u, "v": exact_v, "h": exact_h}

# %% [markdown]
# Now, define the time and spatial domains for mesh generation. The choice of these parameters depends on the specific problem being solved and should be set accordingly.

# %%
time_domain = pinnstorch.data.TimeDomain(t_interval=[0, 1.57079633], t_points = 201)
spatial_domain = pinnstorch.data.Interval(x_interval= [-5, 4.9609375], shape = [256, 1])

# %% [markdown]
# The mesh is then defined using the time and spatial domains along with the read_data_fn function.

# %%
mesh = pinnstorch.data.Mesh(root_dir='/home/sschott/CSCI582-Final-Project/pinns-torch/data',
                            read_data_fn=read_data_fn,
                            spatial_domain = spatial_domain,
                            time_domain = time_domain)

# %% [markdown]
# ### Define Train datasets

# %% [markdown]
# For solving Schrodinger PDE, we have:
# - Initial condition
# - Periodic boundary condition
# - Collection points for the PDE.

# %% [markdown]
# #### Initial Condition
#
# Let's start with initial condition of the Schrodinger.
# $$ u(0, x) = 2 \text{sech}(x) $$
# $$ v(0, x) = 0 $$
#
# For defining initial condition, again we have two options.
#
# - **Sample from the data.**
# - **Defining a function for calculating initial condition.**

# %% [markdown]
# ##### Set number of samples

# %%
N0 = 50

# %% [markdown]
# ##### Option 1: Sample from the data

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        solution = ['u', 'v'])

# %% [markdown]
# The `solution` attribute in `pinnstorch.data.InitialCondition` specifies the solutions (`u` and `v` in our case) to be sampled for initial conditions.

# %% [markdown]
# #### Periodic Boundary Condition

# %% [markdown]
# The `pinnstorch.data.PeriodicBoundaryCondition` is used to sample periodic points from the upper and lower bounds of the spatial domain (mesh). The `derivative_order` parameter specifies the order of the derivative to be matched at these boundaries. In our case, for the Schrödinger equation, both the function and its first spatial derivative should match at the boundaries, hence `derivative_order = 1`.
#
#
# $$ u(t,-5) = u(t, 5), $$
# $$ v(t,-5) = v(t, 5), $$
# $$ u_x(t,-5) = u_x(t, 5),$$
# $$ v_x(t,-5) = v_x(t, 5) $$

# %%
N_b = 50
pe_b = pinnstorch.data.PeriodicBoundaryCondition(mesh = mesh,
                                                 num_sample = N_b,
                                                 derivative_order = 1,
                                                 solution = ['u', 'v'])

# %% [markdown]
# #### Mesh Sampler for collection points and solutions
#
# In our problem, the partial differential equations (PDEs) governing the dynamics are given by:
#
# $$ f_u := u_t + 0.5v_{xx} + v(u^2 +v^2),$$
# $$ f_v := v_t + 0.5u_{xx} + u(u^2 +v^2) $$
#
# To find the solutions to these PDEs using a neural network, we must sample points from the domain at which the network will be trained to satisfy these equations. This sampling process is crucial for training our PINN. We utilize the `pinnstorch.data.MeshSampler` for this purpose, specifying the following:
#
# - **Number of Sample Points (N_f):** We choose to sample 20,000 points from the domain. This number is a balance between computational efficiency and the need for a sufficiently dense sampling to capture the dynamics of the PDEs.
# - **Mesh (mesh):** This parameter defines the spatial-temporal domain from which the points will be sampled.
# - **Collection Points:** We define `['f_u', 'f_v']` as the targets for our collection points. These are not direct outputs from the neural network but are derived from the network outputs and their derivatives (We will define `pde_fn` function later). The PINN will be trained such that these expressions tend towards zero, aligning with the PDE constraints.
#
# Here's the code to implement this sampler:

# %%
N_f = 20000
me_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                   num_sample = N_f,
                                   collection_points = ['f_v', 'f_u'])

# %% [markdown]
# ### Define Validation dataset
#
# For validation, we sample all points from the mesh to evaluate our model comprehensively. Model will be validated for solutions of `u`, `v`, and `h`.
#
# **Note:** If `num_sample` is not specified, the sampler will use the entire mesh for data sampling.

# %%
val_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                    solution = ['u', 'v', 'h'])

# %% [markdown]
# ### Define Neural Networks
#
# Here, we try to define a neural network for solving the problem. For defining a neural network, we should set number of layers and the name of the outputs. Also, domain bounds should be defined. The `lb` and `ub` parameters represent the lower and upper bounds of the spatial-temporal domain, helping in normalizing inputs to the network. Therefore, the inputs of this network are `x` and `t`, and the outputs of this network are `u` and `v`.

# %%
net = pinnstorch.models.FCN(layers = [2, 100, 100, 100, 100, 2],
                            output_names = ['u', 'v'],
                            lb=mesh.lb,
                            ub=mesh.ub)

# %% [markdown]
# ### Define `pde_fn` and `output_fn` functions
#
# Now, we define `pde_fn` and `output_fn`.
# - **`output_fn`:** is applied to the network's output, adding any necessary post-processing computations. For example, in our case, `h(x,t) = u(x,t)**2 + v(x,t)**2`, thus, we define this equation in `output_fn`.
# - **`pde_fn`:** formulates the PDE constraints, which will be used by the `MeshSampler` to compute the loss at the collection points.

# %% [markdown]
# #### `output_fn` function
#
# **Note:** `output_fn` should always have these inputs:
# - **Outputs:** It is output of the network. In our case, this dictionary should have two output: `u` and `v`.
# - **Spatial domains:** These are the spatial domain variables. In our case, because our problem has 1-D spatial domain, the input just have `x`. For example, if we had 2-D space, we need another input for that dimention. For example, the inputs from `(outputs, x, t)` will be changed to `(outputs, x, y, t)`.
# - **Time domin:** The last input of `output_fn` function always should be time.

# %%
def output_fn(outputs: Dict[str, torch.Tensor],
              x: torch.Tensor,
              t: torch.Tensor):
    """Define `output_fn` function that will be applied to outputs of net."""

    outputs["h"] = torch.sqrt(outputs["u"] ** 2 + outputs["v"] ** 2)

    return outputs

# %% [markdown]
# #### `pde_fn` function
#
# The inputs are similar to `output_fn`. Only if we have extra variables for training (i.g. in inverse problems), we should add input at the end of inputs. For example, `(outputs, x, t)` will be `(outputs, x, t, extra_variable)`. `extra_variable` is always a dictionary.

# %%
def pde_fn(outputs: Dict[str, torch.Tensor],
           x: torch.Tensor,
           t: torch.Tensor):
    """Define the partial differential equations (PDEs)."""
    u_x, u_t = pinnstorch.utils.gradient(outputs["u"], [x, t])
    v_x, v_t = pinnstorch.utils.gradient(outputs["v"], [x, t])

    u_xx = pinnstorch.utils.gradient(u_x, x)[0]
    v_xx = pinnstorch.utils.gradient(v_x, x)[0]

    outputs["f_u"] = u_t + 0.5 * v_xx + (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["v"]
    outputs["f_v"] = v_t - 0.5 * u_xx - (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["u"]

    return outputs

# %% [markdown]
# ### Define PINNDataModule and PINNModule
#
# To integrate with Lightning, we utilize two specialized modules:
#
# - `PINNDataModule` (inherited from `LightningDataModule`) manages data.
# - `PINNModule` (derived from `LightningModule`) handles the model, compilation, and various enhancements like AMP.

# %% [markdown]
# #### Define `PINNDataModule`
# Here, we define collection points, initial condition, and preiodic boundary condition as training datasets, and also, we set validation set. `PINNDataModule` is used for defining training, validation, prediction, and test datasets.

# %%
train_datasets = [me_s, in_c, pe_b]
val_dataset = val_s
datamodule = pinnstorch.data.PINNDataModule(train_datasets = [me_s, in_c, pe_b],
                                            val_dataset = val_dataset,
                                            pred_dataset = val_s)

# %% [markdown]
# #### Define `PINNModule`
#
# `PINNModule` handle several things. Here, we will explore the inputs of this class:
# - **net:**  The neural network.
# - **pde_fn:** The function representing the PDE to solve.
# - **optimizer:**  (Optional) The optimizer for training. The default is Adam
# - **loss_fn:** (Optional) The loss function to use, either "sse" or "mse". The default is "sse".
# - **scheduler:** (Optional) Learning rate scheduler. The default is None.
# - **scaler:** (Optional) Gradient scaler for AMP. The default is `torch.cuda.amp.GradScaler`.
# - **extra_variables:** (Optional) Extra variables in inverse problems. The default is None.
# - **output_fn:** (Optional) function to process the model's output. The default is None.
# - **runge_kutta:** (Optional) Runge-Kutta method for solving PDEs in discrete mode. The default is None.
# - **cudagraph_compile:** Flag to enable CUDA Graph compilation. It works only with a single GPU. The default is True.
# - **jit_compile:** (Optional) Flag to enable JIT compilation. The default is True.
# - **amp:** (Optional) Flag to enable Automatic Mixed Precision (AMP). The default is False.
# - **inline:** (Optional) Flag to enable inline mode in JIT compilation. The default is False.
#
# In this example, we initalize `PINNModule` with defined variables. We set Adam optimizer and try to compile the model with CUDA Graph. The loss function here is Mean Square Error (MSE).

# %%
model = pinnstorch.models.PINNModule(net = net,
                                     pde_fn = pde_fn,
                                     output_fn = output_fn,
                                     loss_fn = 'mse')

# %% [markdown]
# ### Setting Up the Trainer
#
# For training our model, we configure a trainer in PyTorch Lightning. Currently, our setup uses a single GPU, as models compiled with CUDA Graph don't support multiple GPUs yet. For a comprehensive understanding of the trainer's options and functionalities, refer to the [official documentation](https://lightning.ai/docs/pytorch/stable/api/lightning.pytorch.trainer.trainer.Trainer.html). For example, arguments that you can set are:
# - **accelerator:**  Supports passing different accelerator types such as `cpu`, `gpu`, `tpu`, `ipu`, `hpu`, `mps`, and `auto`.
# - **devices:** The devices to use. Can be set to a positive number (int or str), a sequence of device indices (list or str), the value -1 to indicate all available devices should be used, or "auto" for automatic selection based on the chosen accelerator. Default: "auto".
# - **max_epochs:** Stop training once this number of epochs is reached.
# - **max_steps:** Stop training after this number of steps.
# - ...
#
# In our example, we configure the trainer for CPU use, specifying one device:

# %%
trainer = pl.Trainer(accelerator='cpu', devices=1, max_epochs=100)
# Out:
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/sschott/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /home/sschott/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %% [markdown]
# ### Training

# %%
trainer.fit(model=model, datamodule=datamodule)
# Out:
#   | Name          | Type       | Params | Mode
# -----------------------------------------------------
# 0 | net           | FCN        | 30.8 K | train
# 1 | train_loss    | MeanMetric | 0      | train
# 2 | val_loss      | MeanMetric | 0      | train
# 3 | val_error     | MeanMetric | 0      | train
# 4 | test_loss     | MeanMetric | 0      | train
# 5 | test_error    | MeanMetric | 0      | train
# 6 | val_loss_best | MinMetric  | 0      | train
# -----------------------------------------------------
# 30.8 K    Trainable params
# 0         Non-trainable params
# 30.8 K    Total params
# 0.123     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/sschott/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:369: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /home/sschott/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:310: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/jit/_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   if a.grad is not None:
# /usr/local/lib/python3.10/dist-packages/torch/jit/_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   if a.grad is not None:
# /usr/local/lib/python3.10/dist-packages/torch/jit/_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   if a.grad is not None:
# /usr/local/lib/python3.10/dist-packages/torch/jit/_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   if a.grad is not None:
# /usr/local/lib/python3.10/dist-packages/torch/jit/_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /opt/pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   if a.grad is not None:
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s, v_num=12, train/loss_step=0.298, val/loss=1.080, val/error_u=0.841, val/error_v=0.974, val/error_h=0.739, val/loss_best=1.080, train/loss_epoch=0.298]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s, v_num=12, train/loss_step=0.298, val/loss=1.080, val/error_u=0.841, val/error_v=0.974, val/error_h=0.739, val/loss_best=1.080, train/loss_epoch=0.298]

# %% [markdown]
# ### Validation

# %%
trainer.validate(model=model, datamodule=datamodule)
# Out:
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        val/error_h        │     0.739445686340332     │
# │        val/error_u        │    0.8412015438079834     │
# │        val/error_v        │    0.9737756848335266     │
# │         val/loss          │    1.0762728452682495     │
# │       val/loss_best       │    1.0762728452682495     │
# └───────────────────────────┴───────────────────────────┘
# [{'val/loss': 1.0762728452682495,
#   'val/error_u': 0.8412015438079834,
#   'val/error_v': 0.9737756848335266,
#   'val/error_h': 0.739445686340332,
#   'val/loss_best': 1.0762728452682495}]

# %% [markdown]
# ### Plotting
#
# For plotting, we need predict the results, and then, we should concatenate the results.

# %%
for _ in range(2000):
    preds_list = trainer.predict(model=model, datamodule=datamodule)
# Out:
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.02it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.54it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.83it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.95it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.95it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.24it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.82it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.48it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.65it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.24it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.64it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.02it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.54it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.77it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.65it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.88it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.97it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.88it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.92it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.75it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.12it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.93it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.68it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.85it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.54it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.97it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.29it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.93it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.24it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.29it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.75it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.92it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.70it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.97it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.14it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.60it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.71it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.95it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.39it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.92it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.10it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.92it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.48it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.64it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.16it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.06it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.48it/s]
# Predicting DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:928, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     925 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     926     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     927 )
# --> 928 results = self._run(model, ckpt_path=ckpt_path)
#     930 assert self.state.stopped
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1012, in Trainer._run(self, model, ckpt_path)
#    1009 # ----------------------------
#    1010 # RUN THE TRAINER
#    1011 # ----------------------------
# -> 1012 results = self._run_stage()
#    1014 # ----------------------------
#    1015 # POST-Training CLEAN UP
#    1016 # ----------------------------
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1051, in Trainer._run_stage(self)
#    1050 if self.predicting:
# -> 1051     return self.predict_loop.run()
#    1052 if self.training:
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/loops/utilities.py:179, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     178 with context_manager():
# --> 179     return loop_run(self, *args, **kwargs)
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/loops/prediction_loop.py:125, in _PredictionLoop.run(self)
#     124     # run step hooks
# --> 125     self._predict_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     126 except StopIteration:
#     127     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/loops/prediction_loop.py:255, in _PredictionLoop._predict_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     250 step_args = (
#     251     self._build_step_args_from_hook_kwargs(hook_kwargs, "predict_step")
#     252     if not using_dataloader_iter
#     253     else (dataloader_iter,)
#     254 )
# --> 255 predictions = call._call_strategy_hook(trainer, "predict_step", *step_args)
#     256 if predictions is None:
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:328, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 328     output = fn(*args, **kwargs)
#     330 # restore current_fx when nested context
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/strategies/strategy.py:438, in Strategy.predict_step(self, *args, **kwargs)
#     437     return self._forward_redirection(self.model, self.lightning_module, "predict_step", *args, **kwargs)
# --> 438 return self.lightning_module.predict_step(*args, **kwargs)
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/models/pinn_module.py:571, in PINNModule.predict_step(self, batch, batch_idx)
#     564 """
#     565 Perform a single predict step on a batch of data from the prediction set.
#     566
#     567 :param batch: A batch of data.
#     568 :param batch_idx: The index of the current batch.
#     569 """
# --> 571 loss, error, preds = self.eval_step(batch)
#     573 return preds
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/models/pinn_module.py:485, in PINNModule.eval_step(self, batch)
#     484 with torch.set_grad_enabled(True):
# --> 485     loss, preds = self.model_step({str(loss_fn): batch})
#     487 if self.rk:
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/models/pinn_module.py:366, in PINNModule.model_step(self, batch)
#     365     x, t = set_requires_grad(x, t, True)
# --> 366     loss, preds = self.function_mapping[loss_fn](data, loss, self.functions)
#     367 return loss, preds
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/data/sampler/sampler_base.py:83, in SamplerBase.loss_fn(self, inputs, loss, functions)
#      81     self.first_batch = False
# ---> 83 loss, outputs = self._loss_fn(inputs, loss)
#      85 return loss, outputs
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/data/sampler/mesh_sampler.py:76, in MeshSampler._loss_fn(self, inputs, loss)
#      74 x, t, u = inputs
# ---> 76 outputs = self.functions["forward"](x, t)
#      78 if self.collection_points_names:
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/models/pinn_module.py:152, in PINNModule.forward(self, spatial, time)
#     146 """Perform a forward pass through the model `self.net`.
#     147
#     148 :param spatial: List of input spatial tensors.
#     149 :param time: Input tensor representing time.
#     150 :return: A tensor of solutions.
#     151 """
# --> 152 outputs = self.net(spatial, time)
#     153 if self.output_fn is not None:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#
# File ~/CSCI582-Final-Project/pinns-torch/pinnstorch/models/net/neural_net.py:92, in FCN.forward(self, spatial, time)
#      90     z = 2.0 * (z - self.lb) / (self.ub - self.lb) - 1.0
# ---> 92 z = self.model(z)
#      94 # Discrete Mode
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     216 for module in self:
# --> 217     input = module(input)
#     218 return input
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 for _ in range(2000):
# ----> 2     preds_list = trainer.predict(model=model, datamodule=datamodule)
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:887, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     885 self.state.status = TrainerStatus.RUNNING
#     886 self.predicting = True
# --> 887 return call._call_and_handle_interrupt(
#     888     self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     889 )
#
# File ~/CSCI582-Final-Project/pinns-torch/.venv/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:65, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63     if isinstance(launcher, _SubprocessScriptLauncher):
#      64         launcher.kill(_get_sigkill_signal())
# ---> 65     exit(1)
#      67 except BaseException as exception:
#      68     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
preds_dict = pinnstorch.utils.fix_predictions(preds_list)

# %%
pinnstorch.utils.plot_schrodinger(mesh=mesh,
                                  preds=preds_dict,
                                  train_datasets=train_datasets,
                                  val_dataset=val_dataset,
                                  file_name='out')
